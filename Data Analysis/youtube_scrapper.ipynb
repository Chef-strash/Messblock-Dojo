# %% [markdown]
# **For all website you can do scrapping in the same way,  so opt to use web drivers**

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
browser= webdriver.Chrome()
browser.get('https://www.youtube.com/@theRadBrad/videos')

# %%
print(browser.page_source)
# Out:
# <html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="en" darker-dark-theme="" darker-dark-theme-deprecate="" dark="" system-icons="" typography="" typography-spacing=""><head><script id="js-1065286052" src="https://www.gstatic.com/cv/js/sender/v1/cast_sender.js" nonce="" data-loaded="true"></script><script id="js-1124342058" src="//static.doubleclick.net/instream/ad_status.js" nonce="" data-loaded="true"></script><script data-original-src="/s/player/94f771d8/player_ias.vflset/en_US/miniplayer.js" nonce="" src="/s/player/94f771d8/player_ias.vflset/en_US/miniplayer.js"></script><script data-original-src="/s/player/94f771d8/player_ias.vflset/en_US/remote.js" nonce="" src="/s/player/94f771d8/player_ias.vflset/en_US/remote.js"></script><script data-original-src="/s/player/94f771d8/player_ias.vflset/en_US/offline.js" nonce="" src="/s/player/94f771d8/player_ias.vflset/en_US/offline.js"></script><script data-id="_gd" nonce="">window.WIZ_global_data = {"HiPsbb":0,"MUE6N
# ...

# %%
soup= BeautifulSoup(browser.page_source, 'html.parser')

# %%
soup.text
# Out:
# 'theRadBrad - YouTube\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n•\n\n\n\n\n\n\n\n\n\n\n\n\nNaN / NaN\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n      Back\n    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  IN\n\n\nSkip navigation\n\n\n\n\n\n\n\n\n        Search\n      \n\n\n\n  Search
# ...

# %%
print(soup.text.replace('\n\n',' '))
# Out:
# theRadBrad - YouTube                                                                                                                                                                               •
# NaN / NaN
#       Back
#
#   IN
# Skip navigation
#         Search
#           Search with your voice    Sign in
#   IN
# Home
#     Home
#
# Shorts
#     Shorts
#
# Subscriptions
#     Subscriptions
#
# You
#     You
#
# History
#     History
#              theRadBrad@theRadBrad•13.8M subscribers•8.8K videos"King of the YouTube Walkthrough" - FMV Magazine ...more...moretwitter.com/thaRadBradand 3 more linksSubscribeJoin
# HomeVideosPlaylistsPosts
#
# Search
#        Previous    Latest  Latest
# Popular  Popular
# Oldest  Oldest     Next
# 2:03:48
#     2:03:48
#   Now playing        2:03:48
# 2:03:48
#     2:03:48
#   Now playing      MINDSEYE Walkthrough Gameplay Part 1 - INTRO (FULL GAME)        Verified  •
# •
# 374K views
# 3 days ago
# 1:12:33
#     1:12:33
# ...

# %%
sp= soup.find('div', id="contents", class_="style-scope ytd-rich-grid-renderer")
print(sp)
# Out:
# <div class="style-scope ytd-rich-grid-renderer" id="contents"><ytd-rich-item-renderer class="style-scope ytd-rich-grid-renderer" is-in-first-column="" is-slim-grid="" items-per-row="3" lockup="true" no-gutter-margins="" rendered-from-rich-grid=""><!--css-build:shady--><!--css_build_scope:ytd-rich-item-renderer--><!--css_build_styles:video.youtube.src.web.polymer.shared.ui.styles.yt_base_styles.yt.base.styles.css.js--><div class="style-scope ytd-rich-item-renderer" id="content"><ytd-rich-grid-media class="style-scope ytd-rich-item-renderer" lockup="true" mini-mode=""><!--css-build:shady--><!--css_build_scope:ytd-rich-grid-media--><!--css_build_styles:video.youtube.src.web.polymer.shared.ui.styles.yt_base_styles.yt.base.styles.css.js--><div class="style-scope ytd-rich-grid-media" id="dismissible"><div class="style-scope ytd-rich-grid-media" id="thumbnail"><ytd-thumbnail class="style-scope ytd-rich-grid-media" loaded="" rich-grid-thumbnail="" size="large" use-hovered-property="" width="
# ...

# %%
len(sp.find_all('ytd-rich-item-renderer'))
# Out:
# 30

# %%
print(sp.find_all('ytd-rich-item-renderer')[2].text)
# Out:
# 1:31:33
#     1:31:33
#   Now playing
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1:31:33
# 1:31:33
#     1:31:33
#   Now playing
#
#
#
#
#
#
#
#
#
#
#
# TORMENTED SOULS 2 - A Classic Survival Horror Game Inspired By RESIDENT EVIL (Full Gameplay)
#
#
#
#
#
#
#
#
#
#
#
#   Verified
#
#
#
# •
#
#
#
#
# •
# 141K views
# 6 days ago

# %%
vid= sp.find('ytd-rich-item-renderer')
title= vid.find('a', id="video-title-link", class_="yt-simple-endpoint focus-on-expand style-scope ytd-rich-grid-media").get('title')
link= vid.find('a', id="video-title-link", class_="yt-simple-endpoint focus-on-expand style-scope ytd-rich-grid-media").get('href')
u_v=vid.find_all('span', class_="inline-metadata-item style-scope ytd-video-meta-block")
views= u_v[0].text
upload= u_v[1].text
duration= vid.find('badge-shape', class_="badge-shape-wiz badge-shape-wiz--thumbnail-default badge-shape-wiz--thumbnail-badge").get('aria-label')

print(title)
print(link)
print(views)
print(upload)
print(duration)
# Out:
# MINDSEYE Walkthrough Gameplay Part 1 - INTRO (FULL GAME)
# /watch?v=Q41D9RLKSsU
# 374K views
# 3 days ago
# 2 hours, 3 minutes, 48 seconds

# %%
data=[]

# %%
data=[]

for vid in sp.find_all('ytd-rich-item-renderer'):
    title= vid.find('a', id="video-title-link", class_="yt-simple-endpoint focus-on-expand style-scope ytd-rich-grid-media").get('title')
    link= vid.find('a', id="video-title-link", class_="yt-simple-endpoint focus-on-expand style-scope ytd-rich-grid-media").get('href')
    uv=[]
    for u_v in vid.find_all('span', class_="inline-metadata-item style-scope ytd-video-meta-block"):
        uv.append(u_v.text)
    duration= vid.find('badge-shape', class_="badge-shape-wiz badge-shape-wiz--thumbnail-default badge-shape-wiz--thumbnail-badge").get('aria-label')
    
    if len(uv)<2:
        data.append([title, duration, "N/A", uv[0], link])
    else:
        data.append([title, duration, uv[0], uv[1], link])

# %%
print(data)
# Out:
# [['MINDSEYE Walkthrough Gameplay Part 1 - INTRO (FULL GAME)', '2 hours, 3 minutes, 48 seconds', '374K views', '3 days ago', '/watch?v=Q41D9RLKSsU'], ['FEROCIOUS - A New DINOSAUR Survival FPS Game Set On A Dangerous Island (Full Gameplay)', '1 hour, 12 minutes, 33 seconds', '188K views', '4 days ago', '/watch?v=9RQRObOMi4A'], ['TORMENTED SOULS 2 - A Classic Survival Horror Game Inspired By RESIDENT EVIL (Full Gameplay)', '1 hour, 31 minutes, 33 seconds', '141K views', '6 days ago', '/watch?v=CZ_7FrzaaK0'], ['MARIO KART WORLD Is Incredible On The SWITCH 2 (Walkthrough Gameplay Part 1)', '1 hour, 1 minute, 59 seconds', '262K views', '10 days ago', '/watch?v=6aYjpZWzByE'], ['RESIDENT EVIL 2 Is An All Time Classic (MAY 2025 MEMBER VIDEO)', '2 hours, 44 seconds', 'N/A', '12 days ago', '/watch?v=Y3XycA3olO0'], ["HELL IS US - A New 3rd-Person Horror Action Game That's INCREDIBLE (Full Gameplay)", '1 hour, 13 minutes, 13 seconds', '742K views', '13 days ago', '/watch?v=-YJOC67c84g'], ['ELDEN 
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

# Setup driver
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(options=options)

# Load channel videos page
channel_url = "xyz"
driver.get(channel_url)

# Scroll loop
last_height = driver.execute_script("return document.documentElement.scrollHeight")
while True:
    # Scroll to bottom
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    time.sleep(2)  # wait for content to load

    # Check new scroll height
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break  # No more content loaded
    last_height = new_height

# Extract info in this section

driver.quit()
